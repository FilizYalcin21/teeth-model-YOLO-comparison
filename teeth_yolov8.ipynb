# %% [markdown]
# # Getting Ready

# %%
# Install ultralytics
# !pip install ultralytics==8
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.6/281.6 kB 11.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# Imports
from IPython.display import Image
import ultralytics
from ultralytics import YOLO

# %% [markdown]
# # Prepare Dataset

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/78.2 GB disk)

# %%
# Make a directory for the dataset
# !mkdir /content/datasets

# %%
# Unzip the dataset zip file
# !unzip /content/teeth.zip -d /content/datasets
# Out:
# Archive:  /content/teeth.zip
#   inflating: /content/datasets/data.yaml
#    creating: /content/datasets/test/images/
#   inflating: /content/datasets/test/images/1009.png
#   inflating: /content/datasets/test/images/1016.png
#   inflating: /content/datasets/test/images/1096.png
#   inflating: /content/datasets/test/images/318.png
#   inflating: /content/datasets/test/images/354.png
#   inflating: /content/datasets/test/images/702.png
#   inflating: /content/datasets/test/images/750.png
#   inflating: /content/datasets/test/images/783.png
#   inflating: /content/datasets/test/images/822.png
#   inflating: /content/datasets/test/images/837.png
#   inflating: /content/datasets/test/images/855.png
#   inflating: /content/datasets/test/images/856.png
#   inflating: /content/datasets/test/images/861.png
#   inflating: /content/datasets/test/images/913.png
#   inflating: /content/datasets/test/images/942.png
#    creating: /content/datasets/test/labels/
# ...

# %% [markdown]
# # Train

# %%
# %cd /content
# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/data.yaml batch=16 epochs=20 imgsz=800 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 180MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# make train >> train2 if you run train the model twice
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %% [markdown]
# # Validate

# %%
# %cd /content
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/datasets/data.yaml
# Out:
# /content
# 2024-05-22 14:22:34.642345: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 14:22:34.642424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 14:22:34.643806: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-22 14:22:34.651539: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt save=True conf=0.7 source=/content/datasets/test/images/1009.png
# Out:
# 2024-05-22 14:25:47.837541: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 14:25:47.837606: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 14:25:47.839038: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-22 14:25:47.847073: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !zip -r yolov8.zip /content/runs/
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 8%)
#   adding: content/runs/detect/train/R_curve.png (deflated 16%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train/args.yaml (deflated 51%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch51.jpg (deflated 19%)
#   adding: content/runs/detect/train/train_batch52.jpg (deflated 16%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/train_batch50.jpg (deflated 19%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 25%)
# ...
